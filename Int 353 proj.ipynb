# %% [markdown]
# # EXPLANATORY DATA ANALYSIS
# DATASET : HOTELS IN GOIBIBO
#
# AS A PART OF EXPLANTORY DATA ANALYSIS(EDA) PROJECT , I SELECTED THE DATASET NAMED "HOTELS IN GOIBIBO" IN WHICH WE ARE GOING TO THE VISUALIZE THE RELATIONS BETWEEN THE RATINGS OF DIFFERENT HOTELS IN DIFFERENT STATES IN INDIA . USING THE LIBRARIES 'NUMPY','PANDAS','MATPLOTLIB','SEABORN','FOLIUM','ITERTOOLS'.
#
# NumPy Library: NumPy can be used to perform a wide variety of mathematical operations.
#
# Pandas Library: It is a python package that offers various operations for manipulating numerical data and time series. It is mainly popular for importing and analyzing data much easier.
#
# Matplotlib Library: Matplotlib is a cross-platform, data visualization and graphical plotting library for python and its numerical extension NumPy.
#
# Seaborn Library: It is a python data visulization library based on matplotlib. It provides a high-level interface for drawing attractive and infromative statistical graphics .
#
# Folium Library: Folium is a powerful pyhton library that helps us create several types of Leaflet maps. By this library we can create inline jupyter maps in folium.
#
# Itertools : Itertools is a module in python , it is used iterate over data structures that can be stepped over using a for-loop. This module works as a fast, memory as a fast, memory-effecient tool thatr is used either by themselves or in combination to form iterator algebra.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import re
import itertools
pd.set_option('max_columns', None)
sns.set_style("white")

# %matplotlib inline

# %% [raw]
# Here I downloaded the csv file of the hotels in goibibo from the resource available to me.I imported that csv file to the jupyter and the next step is to read the data which is available in csv file , which I had mported to the jupyter

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\archive (1)\\goibibo_com-travel_sample.csv")

# %% [markdown]
# The code df.head() returns the output of first five rows of the data

# %%
df.head()
# Out:
#                                      additional_info  \
# 0  Room Service|Internet Access|Restaurant|Free I...
# 1                               Room Service|Gym/Spa
# 2                           Restaurant|Swimming Pool
# 3                                                NaN
# 4                         Internet Access|Restaurant
#
#                                              address            area     city  \
# 0  15th Mile, N.H.21,Manali, District Kullu,Himac...          Others   Manali
# 1  A-585, Sushant Lok-1 ,Near Iffco Chowk Metro S...     Sushant Lok  Gurgaon
# 2  Cobra Vaddo,Calungate Baga Road, Bardez, Calan...  Calangute Area      Goa
# 3                                              Simsa   Village Simsa   Manali
# 4         8180 Street No.-6,Arakashan Road,Paharganj       Paharganj    Delhi
#
#   country  crawl_date  guest_recommendation hotel_brand hotel_category  \
# 0   India  2016-07-24                  85.0         NaN        gostays
# 1   India  2016-07-24                  87.0         NaN        regular
# 2   India  2016-07-24                  50.0         NaN        regular
# 3   India  2016-07-24                 100.0         NaN        regular
# 4   India  2016-07-24                  63.0         NaN        regular
#
#                                    hotel_description  \
# 0  The standard check-in time is 12:00 PM and the...
# 1  The standard check-in time is 12:00 PM and the...
# 2  The standard check-in time is 12:00 PM and the...
# 3  The standard check-in time is 12:00 PM and the...
# 4  The standard check-in time is 12:00 PM and the...
#
#                                     hotel_facilities  hotel_star_rating  \
# 0  Doctor on Call|Dry Cleaning|Laundry Service Av...                  2
# 1  Airport Transfer Available / Surcharge|Banquet...                  0
# 2  Swimming Pool|Bar / Lounge |Laundry Service Av...                  0
# 3  Doctor on Call|Dry Cleaning|Laundry Service Av...                  2
# 4  Internet Access - Surcharge|Laundry Service Av...                  2
#
#    image_count   latitude        locality  longitude  \
# 0           20  32.139387          Others  77.154660
# 1           17  28.472097     Sushant Lok  77.072546
# 2           28  15.548398  Calangute Area  73.757634
# 3            4  32.223603   Village Simsa  77.185900
# 4            6  28.646777       Paharganj  77.212735
#
#                                              pageurl  \
# 0  http://www.goibibo.com/hotels/detail/Manali/hn...
# 1  http://www.goibibo.com/hotels/detail/Gurgaon/h...
# 2  http://www.goibibo.com/hotels/detail/Goa/hn/87...
# 3  http://www.goibibo.com/hotels/detail/Manali/hn...
# 4  http://www.goibibo.com/hotels/detail/Delhi/hn/...
#
#                                    point_of_interest       property_id  \
# 0  Hadimba Temple|Naggar Village|Himalayan Nyingm...  HTLGBO1000016238
# 1  Sushant Lok|Sahara Mall|Amity International Sc...  HTLGBO1000015822
# 2  Anjuna Beach|Calangute Beach|Titos lane, baga|...  HTLGBO1000004551
# 3  The Mall|Tibetian Monastery|Vashisht Hot Baths...  HTLGBO1000007993
# 4  Gaffar Market|YMCA Institute|Agrasen Boali|Cha...  HTLGBO1000008281
#
#          property_name property_type province                        qts  \
# 0     Baragarh Regency        Resort   Manali  2016-07-24 01:12:30 +0000
# 1  Asian Suites A- 585   Guest House  Gurgaon  2016-07-24 01:12:30 +0000
# 2        Bevvan Resort        Resort      Goa  2016-07-24 01:12:30 +0000
# 3    Apple Inn Cottage       Cottage   Manali  2016-07-24 01:12:30 +0000
# 4  Anmol Hotel Pvt.Ltd         Hotel    Delhi  2016-07-24 01:12:30 +0000
#
#             query_time_stamp  \
# 0  2016-07-24 01:12:30 +0000
# 1  2016-07-24 01:12:30 +0000
# 2  2016-07-24 01:12:30 +0000
# 3  2016-07-24 01:12:30 +0000
# 4  2016-07-24 01:12:30 +0000
#
#                             review_count_by_category       room_area  \
# 0  positive reviews::74|critical reviews::13|revi...             NaN
# 1  positive reviews::8|critical reviews::0|review...  14 X 12 Sq.ft.
# 2  positive reviews::1|critical reviews::1|review...             NaN
# 3  positive reviews::1|critical reviews::0|review...             NaN
# 4  positive reviews::56|critical reviews::65|revi...  14 X 14 Sq.ft.
#
#    room_count                                    room_facilities  \
# 0          17  Room Service |Basic Bathroom Amenities|Cable /...
# 1          18  Room Service |Air Conditioning |Basic Bathroom...
# 2          15  Room Service |Air Conditioning |Cable / Satell...
# 3          24  Basic Bathroom Amenities|Cable / Satellite / P...
# 4          20  Basic Bathroom Amenities|Cable / Satellite / P...
#
#                     room_type  \
# 0                 Deluxe Room
# 1  Deluxe Room With Free WIFI
# 2               Standard Room
# 3                 Deluxe Room
# 4        Standard Room Non AC
#
#                                        similar_hotel  site_review_count  \
# 0  https://www.goibibo.com/hotels/woodchime-homes...               87.0
# 1  https://www.goibibo.com/hotels/stepinn-iffco-c...                8.0
# 2  https://www.goibibo.com/hotels/sunrise-beach-r...                2.0
# 3  https://www.goibibo.com/hotels/green-cottages-...                1.0
# 4  https://www.goibibo.com/hotels/delhi-continent...              121.0
#
#    site_review_rating                            site_stay_review_rating  \
# 0                 4.0  Service Quality::3.9|Amenities::3.7|Food and D...
# 1                 4.5  Service Quality::4.7|Amenities::4.7|Food and D...
# 2                 2.5  Service Quality::2.5|Amenities::2.5|Food and D...
# 3                 5.0  Service Quality::5.0|Amenities::5.0|Food and D...
# 4                 2.8  Service Quality::2.7|Amenities::2.6|Food and D...
#
#   sitename             state                           uniq_id
# 0  goibibo  Himachal Pradesh  2c8db027d43a9452a43e88eb30d9f983
# 1  goibibo           Haryana  e98f69f889c0235e6dc480e7df6de0de
# 2  goibibo               Goa  9b59d00eaffc273d83000ed7dcda0e83
# 3  goibibo  Himachal Pradesh  df0971f9c5501af112485ee28b468ce5
# 4  goibibo             Delhi  0c3514344c9cda8718f558e84bdb44ef

# %% [markdown]
# Now the code df.tail() returns the output of last five rows of the data

# %%
df.tail()
# Out:
#               additional_info  \
# 3995             Room Service
# 3996             Room Service
# 3997  Room Service|Restaurant
# 3998             Room Service
# 3999  Room Service|Restaurant
#
#                                                 address                  area  \
# 3995      Vijayvargiya Tower,Tower Chowk, Ujjain (M.P.)         Freeganj Area
# 3996     Anjali Circle ,Opposite Petrol Pump,Vasna Road     Ellis Bridge Area
# 3997  Marol Maroshi Road, Near To Marol naka FireBri...               Andheri
# 3998      Station Road, B Deoghar Ho, Deoghar Jharkhand  Railway Station Road
# 3999                     N.H 6, A.Katapali, Near Gosala              Katapali
#
#            city country  crawl_date  guest_recommendation hotel_brand  \
# 3995     Ujjain   India  2016-06-26                   NaN         NaN
# 3996  Ahmedabad   India  2016-06-26                   NaN         NaN
# 3997     Mumbai   India  2016-06-26                  83.0         NaN
# 3998    Deoghar   India  2016-06-26                   NaN         NaN
# 3999  Sambalpur   India  2016-06-26                  50.0         NaN
#
#      hotel_category                                  hotel_description  \
# 3995        regular  The standard check-in time is 12:00 PM and the...
# 3996        regular  The standard check-in time is 02:00 PM and the...
# 3997        regular  The standard check-in time is 12:00 PM and the...
# 3998        regular  The standard check-in time is 02:00 PM and the...
# 3999        regular  The standard check-in time is 10:00 AM and the...
#
#                                        hotel_facilities  hotel_star_rating  \
# 3995  Doctor on Call|Parking Facilities Available|Pa...                  0
# 3996  Doctor on Call|Laundry Service Available|Parki...                  0
# 3997  Banquet Facilities|Bar / Lounge |Currency Exch...                  3
# 3998  Business Center |Disabled Friendly Facilities ...                  1
# 3999  Business Center |Doctor on Call|Parking Facili...                  2
#
#       image_count   latitude              locality  longitude  \
# 3995           13  23.179301         Freeganj Area  75.784910
# 3996           23  23.004443     Ellis Bridge Area  72.552796
# 3997           19  19.110926               Andheri  72.879038
# 3998            9  24.511849  Railway Station Road  86.696999
# 3999            6  21.448978              Katapali  83.912502
#
#                                                 pageurl  \
# 3995  http://www.goibibo.com/hotels/detail/Ujjain/hn...
# 3996  http://www.goibibo.com/hotels/detail/Ahmedabad...
# 3997  http://www.goibibo.com/hotels/detail/Mumbai/hn...
# 3998  http://www.goibibo.com/hotels/detail/Deoghar/h...
# 3999  http://www.goibibo.com/hotels/detail/Sambalpur...
#
#                                       point_of_interest       property_id  \
# 3995  Freeganj Area|Mahakal Temple|Kaliadeh Palace|B...  HTLGBO1000087842
# 3996  St Xaviers College|Sarkhej Roza|HCG Multi Spec...  HTLGBO1000058558
# 3997  Mount Mary Church|Juhu Beach|Domestic Airport|...  HTLGBO1000001584
# 3998  Ramakrishna Mission Vidyapeeth|Shivaganga|Rail...  HTLGBO1000085234
# 3999                                           Katapali  HTLGBO1000071918
#
#                    property_name property_type   province  qts  \
# 3995      Hotel Shreenath Palace         Hotel     Ujjain  NaN
# 3996             Hotel Sarvottam         Hotel  Ahmedabad  NaN
# 3997            Hotel Silver Inn         Hotel     Mumbai  NaN
# 3998  Hotel Shivam International         Hotel    Deoghar  NaN
# 3999           Hotel Silver Moon         Hotel  Sambalpur  NaN
#
#                query_time_stamp  \
# 3995  2016-06-26 05:31:53 +0000
# 3996  2016-06-26 05:31:53 +0000
# 3997  2016-06-26 05:31:53 +0000
# 3998  2016-06-26 05:31:53 +0000
# 3999  2016-06-26 05:31:53 +0000
#
#                                review_count_by_category room_area  room_count  \
# 3995                                                NaN       NaN          10
# 3996                                                NaN       NaN          12
# 3997  positive reviews::64|critical reviews::13|revi...       NaN          41
# 3998                                                NaN       NaN           4
# 3999  positive reviews::2|critical reviews::0|review...       NaN           8
#
#                                         room_facilities        room_type  \
# 3995                                                NaN  Two bed AC Room
# 3996  Room Service |Air Conditioning |Basic Bathroom...      Non AC Room
# 3997  Air Conditioning |Cable / Satellite / Pay TV a...        Gold Room
# 3998  Room Service |Air Conditioning |Alarm Clock|Ba...   AC DELUXE ROOM
# 3999  Room Service |Basic Bathroom Amenities| Hot / ...   Deluxe AC Room
#
#                                           similar_hotel  site_review_count  \
# 3995  https://www.goibibo.com/hotels/avantika-hotel-...                NaN
# 3996  https://www.goibibo.com/hotels/heritage-hotel-...                NaN
# 3997  https://www.goibibo.com/hotels/marigold-reside...               77.0
# 3998  https://www.goibibo.com/hotels/yashoda-interna...                NaN
# 3999  https://www.goibibo.com/hotels/ashoka-hotel-ho...                2.0
#
#       site_review_rating                            site_stay_review_rating  \
# 3995                 NaN  Service Quality::|Amenities::|Food and Drinks:...
# 3996                 NaN  Service Quality::|Amenities::|Food and Drinks:...
# 3997                 4.0  Service Quality::3.9|Amenities::3.8|Food and D...
# 3998                 NaN  Service Quality::|Amenities::|Food and Drinks:...
# 3999                 4.3  Service Quality::4.3|Amenities::4.3|Food and D...
#
#      sitename           state                           uniq_id
# 3995  goibibo  Madhya Pradesh  9e59170d5f79ebb7b590ed339e3762a4
# 3996  goibibo         Gujarat  c0f3e4dac166df972277c86243b27560
# 3997  goibibo     Maharashtra  38b95f3e67046131254d3e2106b9d8fa
# 3998  goibibo       Jharkhand  eb8597d68508134dedc811c2a4fc42b4
# 3999  goibibo          Orissa  ae587589415630183abc91d5f2fd3de4

# %% [markdown]
# df.shape() gives the output result the number of rows and columns that datatset is consisting.

# %%
df.shape
# Out:
# (4000, 36)

# %% [markdown]
# df.info() gives the output that the total columns that data consists and the no.of non-null entries in the data and the data
# type whether it is a object ,float,integer etc....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   additional_info           3192 non-null   object
#  1   address                   4000 non-null   object
#  2   area                      3965 non-null   object
#  3   city                      4000 non-null   object
#  4   country                   4000 non-null   object
#  5   crawl_date                4000 non-null   object
#  6   guest_recommendation      2416 non-null   float64
#  7   hotel_brand               389 non-null    object
#  8   hotel_category            4000 non-null   object
#  9   hotel_description         3983 non-null   object
#  10  hotel_facilities          3806 non-null   object
#  11  hotel_star_rating         4000 non-null   int64
#  12  image_count               4000 non-null   int64
#  13  latitude                  4000 non-null   float64
#  14  locality                  3965 non-null   object
#  15  longitude                 4000 non-null   float64
#  16  pageurl                   4000 non-null   object
#  17  point_of_interest         3760 non-null   object
#  18  property_id               4000 non-null   object
#  19  property_name             4000 non-null   object
#  20  property_type             4000 non-null   object
#  21  province                  4000 non-null   object
#  22  qts                       2716 non-null   object
#  23  query_time_stamp          4000 non-null   object
#  24  review_count_by_category  2415 non-null   object
#  25  room_area                 1128 non-null   object
#  26  room_count                4000 non-null   int64
#  27  room_facilities           3730 non-null   object
#  28  room_type                 4000 non-null   object
#  29  similar_hotel             3917 non-null   object
#  30  site_review_count         2416 non-null   float64
#  31  site_review_rating        2416 non-null   float64
#  32  site_stay_review_rating   4000 non-null   object
#  33  sitename                  4000 non-null   object
#  34  state                     4000 non-null   object
#  35  uniq_id                   4000 non-null   object
# dtypes: float64(5), int64(3), object(28)
# memory usage: 1.1+ MB

# %% [markdown]
# Here df.describe() gives the total summary of the data by mean, median,mode and total count

# %%
df.describe()
# Out:
#        guest_recommendation  hotel_star_rating  image_count     latitude  \
# count           2416.000000        4000.000000  4000.000000  4000.000000
# mean              75.537666           1.306000    12.995500    21.288213
# std               22.698935           1.479159    11.631113     7.576905
# min                0.000000           0.000000     0.000000     8.080476
# 25%               67.000000           0.000000     6.000000    13.748553
# 50%               80.000000           1.000000     9.000000    22.225083
# 75%               90.000000           3.000000    17.000000    28.018203
# max              100.000000           5.000000   129.000000    79.608077
#
#          longitude   room_count  site_review_count  site_review_rating
# count  4000.000000  4000.000000        2416.000000         2416.000000
# mean     77.432995    22.200250          47.765728            3.750993
# std       4.506588    96.132138          93.233924            0.842863
# min      12.939682     0.000000           0.000000            0.000000
# 25%      74.723694     7.000000           4.000000            3.400000
# 50%      76.967365    14.000000          17.000000            3.900000
# 75%      78.286097    26.000000          55.000000            4.300000
# max      95.346775  5874.000000        2094.000000            5.000000

# %% [markdown]
# df.shape() gives the output result the number of rows and columns that datatset is consisting.

# %%
df.shape
# Out:
# (4000, 36)

# %% [markdown]
# df.isnull() is used for verifying whether dataset consists of an null entries and in the output we can clearly observe that the column "hote_brand" is a null entry.

# %%
df.isnull()
# Out:
#       additional_info  address   area   city  country  crawl_date  \
# 0               False    False  False  False    False       False
# 1               False    False  False  False    False       False
# 2               False    False  False  False    False       False
# 3                True    False  False  False    False       False
# 4               False    False  False  False    False       False
# ...               ...      ...    ...    ...      ...         ...
# 3995            False    False  False  False    False       False
# 3996            False    False  False  False    False       False
# 3997            False    False  False  False    False       False
# 3998            False    False  False  False    False       False
# 3999            False    False  False  False    False       False
#
#       guest_recommendation  hotel_brand  hotel_category  hotel_description  \
# 0                    False         True           False              False
# 1                    False         True           False              False
# 2                    False         True           False              False
# 3                    False         True           False              False
# 4                    False         True           False              False
# ...                    ...          ...             ...                ...
# 3995                  True         True           False              False
# 3996                  True         True           False              False
# 3997                 False         True           False              False
# 3998                  True         True           False              False
# 3999                 False         True           False              False
#
#       ...  room_count  room_facilities  room_type  similar_hotel  \
# 0     ...       False            False      False          False
# 1     ...       False            False      False          False
# 2     ...       False            False      False          False
# 3     ...       False            False      False          False
# 4     ...       False            False      False          False
# ...   ...         ...              ...        ...            ...
# 3995  ...       False             True      False          False
# 3996  ...       False            False      False          False
# 3997  ...       False            False      False          False
# 3998  ...       False            False      False          False
# 3999  ...       False            False      False          False
#
#       site_review_count  site_review_rating  site_stay_review_rating  \
# 0                 False               False                    False
# 1                 False               False                    False
# 2                 False               False                    False
# 3                 False               False                    False
# 4                 False               False                    False
# ...                 ...                 ...                      ...
# 3995               True                True                    False
# 3996               True                True                    False
# 3997              False               False                    False
# 3998               True                True                    False
# 3999              False               False                    False
#
#       sitename  state  uniq_id
# 0        False  False    False
# 1        False  False    False
# 2        False  False    False
# 3        False  False    False
# 4        False  False    False
# ...        ...    ...      ...
# 3995     False  False    False
# 3996     False  False    False
# 3997     False  False    False
# 3998     False  False    False
# 3999     False  False    False
#
# [4000 rows x 36 columns]

# %% [markdown]
# The below code result us the no.of unique cities in the dataset

# %%
len(df['city'].unique())
# Out:
# 558

# %% [markdown]
# Below code gives the output of city consisting maximum no.of hotels .
# AND GOA IS THAT PLACE WHICH CONSIST OF MAXIMUM NO.OF HOTELS AND FOLLOWED BY THE BANGLORE,DELHI,GURGAON AND CHENNAI.

# %%
df['city'].value_counts().head()
# Out:
# Goa          220
# Bangalore    170
# Delhi        137
# Gurgaon      101
# Chennai       86
# Name: city, dtype: int64

# %%
df['hotel_star_rating'].value_counts()
# Out:
# 0    1936
# 3     829
# 2     479
# 1     442
# 4     233
# 5      81
# Name: hotel_star_rating, dtype: int64

# %%
df['room_count'].describe()
# Out:
# count    4000.000000
# mean       22.200250
# std        96.132138
# min         0.000000
# 25%         7.000000
# 50%        14.000000
# 75%        26.000000
# max      5874.000000
# Name: room_count, dtype: float64

# %%
room_count = df['room_count']
room_count.dropna(inplace = True)
plt.figure(figsize=(15,10))
plt.title('Distribution Plot', fontsize=18)
plt.xlabel('xlabel',fontsize=18)
sns.distplot(df['room_count'] , color='g')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Distribution Plot'}, xlabel='room_count', ylabel='Density'>

# %%
plt.figure(figsize=(15, 5))
plt.title('Box Plot', fontsize=18)
plt.xlabel('xlabel',fontsize=18)
sns.boxplot(df['room_count'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Box Plot'}, xlabel='room_count'>

# %%
room_count = df['hotel_star_rating']
room_count.dropna(inplace = True)
plt.figure(figsize=(15, 5))
plt.title('Count Plot', fontsize=18)
plt.xlabel('xlabel',fontsize=18)
sns.countplot(df['hotel_star_rating'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Count Plot'}, xlabel='hotel_star_rating', ylabel='count'>

# %%
plt.figure(figsize = (15,10))
plt.title('Count Plot (Hotels by States)', fontsize=18)
plt.xticks(rotation = (90))
plt.xlabel('xlabel',fontsize=18)
sns.countplot(df['state'], palette="Set2")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Count Plot (Hotels by States)'}, xlabel='state', ylabel='count'>

# %% [markdown]
# COUNT PLOTS
# COUNT PLOTS METHOD IS USED TO SHOW THE COUNTS OF OBSERVATION IN EACH CATEGORICAL BIN USING BARS. COUNTPLOTS ARE USED BY SEABORN.
#
# DENSITY PLOTS
# DENSITY PLOTS IS A TYPE OF DATA VISUALIZATION TOOL. IT IS A VARIATION OF THE HISTOGRAM THAT USES 'KERNEL SMOOTHING' WHILE PLOTTING THE VALUES. "KERNEL SMOOTHING" CAN REVEAL AND PERSERVE STRUCTURAL FEATURES OF A "PROBABILITY DENSITY FUNCTION" THAT A PARAMETRIC ESTIMATE WOULD OBSCURE.
#
# IN THE BELOW ANALYSIS I USED THE DENSITY FUNCTION FOR "SITE_REVIEW_RATING","SITE_REVIEW_COUNT","ROOM COUNT" AND COUNTPLOT IS USED FOR "HOTEL_STAR_RATING"

# %%
f, axarr = plt.subplots(2, 2, figsize=(14, 8))
plt.suptitle('Goibibo Hotel Breakdown', fontsize=18)

sns.kdeplot(df['site_review_rating'], ax=axarr[0][0])
sns.kdeplot(df['site_review_count'], ax=axarr[0][1])
sns.countplot(df['hotel_star_rating'], ax=axarr[1][0])
sns.kdeplot(df['room_count'], ax=axarr[1][1])

sns.despine()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.iloc[df['room_count'].argmax()]['pageurl']
# Out:
# 'http://www.goibibo.com/hotels/detail/Jaisalmer/hn/8665923561677193166/1052461952279511604/na/hq/'

# %%
sns.jointplot(df.hotel_star_rating, df.site_review_rating)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# THERE IS A VERY STRONG LIFT THAT'S VISIBLE HERE. 4-STAR AND ESPECIALLY 5-STAR HOTELS HAVE SIGNIFICANTLY BETTER RATINGS THAN LOWER-STARRED OPTIONS. AS A RULE OF THUMB, STAYING AT A 3-MINUS-STAR-HOTEL RISKS HAVING A TERRIBLE EXPERIENCE , STAYING AT A 4-STAR HOTELS MEANS YOU WILL HAVE AT AN UNSATIFACTORY EXPERINECE IN THE HOTELS LIKE(2/5 RATING); AND STAYING AT A 5-STAR RATING HOTELS GUARANTEE THAT ATLEAST YOUN HAVE BETTER EXPERIENCE THAN AN LOWER RATED HOTELS.
#
# Effect of amenities on price
# Here we take a look at whether a hotel is offering or not offering a specific amenity and is that affect on the star rating of the hotel.
#
# We use the module iter tools that help us to iterate the top amenities among the hotels till the conditions like room facilities etc..are in the hotels.

# %%
import itertools

top_amenities = pd.Series(
    list(itertools.chain(*df['room_facilities']\
                             .fillna("")\
                             .map(lambda f: [am.strip() for am in f.split("|")])\
                             .values\
                             .tolist()))).value_counts().head(12).index.values
temp = df.assign(amenities=df['room_facilities'].fillna("").map(
        lambda f: [am.strip() for am in f.split("|")]))

for amenity in top_amenities:
    temp[amenity] = temp.amenities.map(lambda l: amenity in l)

# %%
top_amenities
# Out:
# array(['Room Service', 'Basic Bathroom Amenities',
#        'Hot / Cold Running Water', 'Housekeeping', 'Ceiling Fan',
#        'Air Conditioning', 'Cable / Satellite / Pay TV available',
#        'Attached Bathroom', 'Telephone', 'Mirror', 'TV', 'Desk in Room'],
#       dtype=object)

# %% [markdown]
# Now by using the itertools we got the top amenities in the total hotels and now we will use the seaborn library to represent different amenities comparing to the different hotels .
#
# Categorical data analysis
# Here we use factorplot to represent the room service among the hotel_star_rating
# Factor plot: It used to draw a different types of categorical plots.
#
# Amenities can have strong effects on hotel star-ratings. Most surprisingly, having room service is a downward trend, while housekeeping is upwards! This is not due to the amenities themselves -- nobody would rather not have room service then have it -- but rather tells us something about the kinds of hotels these fields get attached to. Perhaps housekeeping is an upgraded version of room service specific to higher-quality hotels!

# %%
f, axarr = plt.subplots(3, 4, figsize=(14, 8))
f.subplots_adjust(hspace=1)

sns.factorplot(x='Room Service', y='hotel_star_rating', data=temp.dropna(), ax=axarr[0][0])
axarr[0][0].set_title("Room Service?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Room Service?')

# %%
sns.factorplot(x='Basic Bathroom Amenities', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[0][1])
axarr[0][1].set_title("Basic Bathroom Amenities?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Basic Bathroom Amenities?')

# %%
sns.factorplot(x='Hot / Cold Running Water', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[0][2])
axarr[0][2].set_title("Hot / Cold Running Water?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Hot / Cold Running Water?')

# %%
sns.factorplot(x='Housekeeping', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[0][3])
axarr[0][3].set_title("Housekeeping?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Housekeeping?')

# %%
sns.factorplot(x='Ceiling Fan', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[1][0])
axarr[1][0].set_title("Ceiling Fan?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Ceiling Fan?')

# %%
sns.factorplot(x='Air Conditioning', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[1][1])
axarr[1][1].set_title("Air Conditioning?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Air Conditioning?')

# %%
sns.factorplot(x='Cable / Satellite / Pay TV available', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[1][2])
axarr[1][2].set_title("Cable / Satellite / Pay TV?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Cable / Satellite / Pay TV?')

# %%
sns.factorplot(x='Attached Bathroom', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[1][3])
axarr[1][3].set_title("Attached Bathroom?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Attached Bathroom?')

# %%
sns.factorplot(x='Telephone', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[2][0])
axarr[2][0].set_title("Telephone?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Telephone?')

# %%
sns.factorplot(x='Mirror', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[2][1])
axarr[2][1].set_title("Mirror?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'Mirror?')

# %%
sns.factorplot(x='TV', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[2][2])
axarr[2][2].set_title("TV?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'TV?')

# %%
sns.factorplot(x='TV', y='site_review_rating', 
               data=temp.dropna(), ax=axarr[2][2])
axarr[2][2].set_title("TV?")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.0, 'TV?')

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.13.0-py2.py3-none-any.whl (96 kB)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from folium) (2.26.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: jinja2>=2.9 in c:\users\dell\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\dell\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests->folium) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests->folium) (3.2)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Hotel locations
#
# The number of hotels in a particular city is strongly, but not totally, dependent on the size of the city in question. For example, the city of Gao, with ~1.5 million residents and a strong tourism industry, has about the same sample size of hotels in this dataset than Bangalore, a city of ~18 million (metro area population). I believe that some of this is due to variance in definitions, regional differences in what platforms hotels in an area use (India is a really big country), and possibly data sampling issues on PromptCloud's end; but we should nevertheless have a reasonable estimate of distribution of hotels in India.

# %%
df_lat_long = df.groupby('city').first().loc[:, ['longitude', 'latitude']].assign(
    n_df = df.groupby('city').area.count(),
    n_reviews = (df.assign(site_review_count=df.site_review_count.fillna(0))\
                 .groupby('city').site_review_count.sum())
)

# %%
import folium

m = folium.Map(
    location=[21.15, 79.09],
    zoom_start=4
)

max_n_df = df_lat_long.n_df.max()

df_lat_long.apply(lambda ll: folium.Circle(radius=200000 * (ll.n_df / max_n_df),
                                               location=[ll.latitude, ll.longitude],
                                               fill=True,
                                               color='black',
                                               popup=ll.name).add_to(m), axis='columns')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6b610c79e4b5cb094d5af173b915c86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6b610c79e4b5cb094d5af173b915c86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e6b610c79e4b5cb094d5af173b915c86 = L.map(
#                 &quot;map_e6b610c79e4b5cb094d5af173b915c86&quot;,
#                 {
#                     center: [21.15, 79.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b931070ef1dbc7fb7612cfa1f873afd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e6b610c79e4b5cb094d5af173b915c86);
#
#
#             var circle_92e3b760129c80c5982bcddfa8f4043b = L.circle(
#                 [30.147064, 74.2028122],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 909.090909090909, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e6b610c79e4b5cb094d5af173b915c86);
#
#
#         var popup_f5052fd56556ea1e0dc904acb3c7189b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ca1516bc4005b99a0315aae1b6d0f63 = $(`&lt;div id=&quot;html_0ca1516bc4005b99a0315aae1b6d0f63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abohar&lt;/div&gt;`)[0];
#                 popup_f5052fd56556ea1e0dc904acb3c7189b.setContent(html_0ca1516bc4005b99a0315aae1b6d0f63);
#
#
#
#         circle_92e3b760129c80c5982bcddfa8f4043b.bindPopup(popup_f5052fd56556ea1e0dc904acb3c7189b)
#         ;
#
#
#
#
#             var circle_2186e4264aab6922c03ad083b7658bfc = L.circle(
#                 [24.3792801, 92.1619112],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2727.272727272727, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e6b610c79e4b5cb094d5af173b915c86);
#
#
#         var popup_95e8f64312c450acba55dd28f34ae618 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f8867216d08f50ae6e24dd68a6d9e3a = $(`&lt;div id=&quot;html_9f8867216d08f50ae6e24dd68a6d9e3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agartala&lt;/div&gt;`)[0];
#                 popup_95e8f64312c450acba55dd28f34ae618.setContent(html_9f8867216d08f50ae6e24dd68a6d9e3a);
#
#
#
#         circle_2186e4264aab6922c03ad083b7658bfc.bindPopup(popup_95e8f64312c450acba55dd28f34ae618)
#         ;
#
#
#
#
#             var circle_792be257f9852d8450c84b4b59d83914 = L.circle(
#                 [27.2070155372, 77.9716572646],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 35454.545454545456, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e6b610c79e4b5cb094d5af173b915c86);
#
#
#         var popup_6740b95d58669ee63c6e551dd0fafe78 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfda488e72e859978e1c967d2d455269 = $(`&lt;div id=&quot;html_dfda488e72e859978e1c967d2d455269&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Agra&lt;/div&gt;`)[0];
#                 popup_6740b95d58669ee63c6e551dd0fafe78.setContent(html_dfda488e72e859978e1c967d2d455269);
#
#
#
#         circle_792be257f9852d8450c84b4b59d83914.bindPopup(popup_6740b95d58669ee63c6e551dd0fafe78)
#         ;
#
#
#
#
#             var circle_0c3ef9ee5c2a825d99c29d0d60067558 = L.circle(
#                 [19.0952075, 74.7495916],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot

# %%
def plotCorrelationMatrix(df, graphWidth):
    filename = df
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for {filename}', fontsize=15)
    plt.show()

# %%
plotCorrelationMatrix(df, 8)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_6184/2107229382.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df = df.dropna('columns') # drop columns with NaN

# %%
_ = (df[[col for col in df.columns if "_rating" in col]]
          .dropna()
          .sample(100))
_.columns = pd.Series([col for col in df.columns if "_rating" in col]).str.replace("_rating", "")

sns.pairplot(_, size=1.4)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
